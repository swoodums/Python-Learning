# %% [markdown]
# <a href="https://colab.research.google.com/github/swoodums/Python-Learning/blob/main/pandasLesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# I want to analyze the California Housing Data (test data set).

# %%
from google.colab import files
uploaded = files.upload()  #prompts picking the file to upload
# Out:
#      <input type="file" id="files-a5ce9127-0fc1-4d7f-a83f-48b71b45d234" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5ce9127-0fc1-4d7f-a83f-48b71b45d234">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving california_housing_test.csv to california_housing_test (2).csv

# %%
h = pd.read_csv("california_housing_test.csv")  #loads the csv data into pandas DataFrame "h"
h
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# I want to see the first and last 8 rows of data.

# %%
h.head(8)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2992       232.0        92.0         6.2263            500001.0
# 2993       673.0       390.0         5.1048            500001.0
# 2994       516.0       174.0         5.5867            182500.0
# ...

# %%
h.tail(8)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2992       232.0        92.0         6.2263            500001.0
# 2993       673.0       390.0         5.1048            500001.0
# 2994       516.0       174.0         5.5867            182500.0
# ...

# %% [markdown]
# What is are the data types for each column in this data?

# %%
h.dtypes  #No brackets or parenthesis needed since dtpyes is an attribute of a DataFrame.  Methods need brackets to do something to the DataFrame.
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# My colleauge requested the housing data as a spreadsheet.

# %%
h.to_excel("california_housing_test.xlsx", sheet_name="Housing Data", index=False)

# %%
files.download("california_housing_test.xlsx")

# %% [markdown]
# I'm interested in a technical summary of a DataFrame.

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
